# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.dates as mdates
import seaborn as sns
import pandas as pd
import numpy as np
import os as os
import netCDF4
import xarray as xr
import rasterio
import xarray as xr
from utils import plot_diurnal_and_amplitude_side_by_side

# %%
file = r"C:\Users\pparvizi24\OneDrive - University of Oulu and Oamk\Parsa-PHD-OneDrive\DTS\Dataset - All\Filtered.nc"
data = xr.open_dataset(file, engine='netcdf4')

# %%
# Canopy fraction CSV path (update with your actual path)
canopy_path = r"C:\Users\pparvizi24\OneDrive - University of Oulu and Oamk\Parsa-PHD-OneDrive\DTS\Dataset - All\WBT_tools-main\results\canopy_stream_analysis\pallas_canopy_along_streams.csv"

# %%
# Define dates
dates = ['2022-06-06', '2022-06-07', '2022-06-25', 
         '2022-07-09', '2022-07-10', '2022-07-25']


# Create the plots
plot_diurnal_and_amplitude_side_by_side(
    data=data,
    dates=dates,
    start_hour=12,
    end_hour=16,
    canopy_csv_path=canopy_path  # Canopy will be plotted on right y-axis of left plot
)
